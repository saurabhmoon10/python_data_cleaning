# %% [markdown]
# # PART-1

# %%
# importing the necessary libraries.
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# loading the dataset in notebook
data= pd.read_csv(r"C:\Users\HP\Downloads\winequality_red.csv-20240123T095601Z-001\winequality_red.csv")

# %%
# checking the overview of the dataset
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
# shape format of dataset
data.shape
# Out:
# (1599, 12)

# %% [markdown]
#  * We have 1599 rows and 12 columns.

# %%
# copying the dataset in new variable for performing the tasks.
data_copy=data.copy()

# %%
# checking the overview again
data_copy.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data_copy.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# * The dataset is successfully copied in our data_copy variable.

# %%
# checking the information of dataset
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# * We have 12 columns containing numeric values in it.

# %%
# checking the shape format of data
data_copy.shape
# Out:
# (1599, 12)

# %%
# describing the dataset based on this statistical values
data_copy.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
# finding null values
data_copy.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
# calculating the sum of null values present in it.
data_copy.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# * We do not have null values in it.

# %%
data_copy.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %% [markdown]
# * We can observe that :-
#
#     * When wine quality is bad its volatile acidity is high and as its wine quality good then its volatile acidity is low.
#
#     * When wine quality is bad its has low cirtric acid and as its quality is good then its cirtric acid is high.
#
#     * When wine quality is bad then its has high ph value and when quality is good then its has low ph value.

# %% [markdown]
# # EDA

# %%
# plot the correlational plot using heat map
plt.figure(figsize=(10,8))
sb.heatmap(data_copy.corr(),annot=True)
# Out:
# <Axes: >

# %%
# plotting the countplot of target column 'quality'.
plt.figure(figsize=(5,5))
sb.countplot(x="quality",data=data_copy)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %% [markdown]
# * We have the maximum number of counts for quality 5 and 6.

# %%
# checking the histplot
for i in data_copy:
    plt.figure(figsize=(10,10))
    sb.histplot(x=data_copy[i])

# %%
# another method for doing the same
data_copy.hist(figsize=(10,10),bins=50)
plt.show()

# %%
# checking for outliers using boxplot.
for i in data_copy:
    plt.figure(figsize=(8,1))
    sb.boxplot(x=data_copy[i])

# %% [markdown]
# * We have outliers in our dataset.

# %%
# we will handle it later using the IQR concept .

# %% [markdown]
# ## Feature Selection

# %%
data_copy.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1423            6.4              0.53         0.09             3.9      0.123
# 1405            7.7              0.28         0.30             2.0      0.062
# 1298            5.7              0.60         0.00             1.4      0.063
# 1457            7.6              0.49         0.33             1.9      0.074
# 1394            6.4              0.57         0.14             3.9      0.070
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1423                 14.0                  31.0  0.99680  3.50       0.67
# 1405                 18.0                  34.0  0.99520  3.28       0.90
# 1298                 11.0                  18.0  0.99191  3.45       0.56
# 1457                 27.0                  85.0  0.99706  3.41       0.58
# 1394                 27.0                  73.0  0.99669  3.32       0.48
#
#       alcohol  quality
# 1423     11.0        4
# ...

# %%
# cheecking the unique values of quality columns.
data_copy["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# * There are 6 unique values present in it.

# %%
# checking total number of good vs bad quality wine
data_copy["good_quality"].value_counts()
# Out:
# good_quality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %% [markdown]
# * There are 217 good quality wines .

# %%
# if wine quality is 7 or above than we will consider it as good quality wine.
# created new column which is based on categorial values.
data_copy["good_quality"]=[1 if q >=7 else 0 for q in data_copy["quality"]]

# %%
# checking the sample of it.
data_copy.sample(15)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1281            7.1              0.46         0.20            1.90      0.077
# 344            11.9              0.57         0.50            2.60      0.082
# 533            10.3              0.27         0.24            2.10      0.072
# 1006            9.1              0.29         0.33            2.05      0.063
# 407            12.0              0.39         0.66            3.00      0.093
# 326            11.6              0.53         0.66            3.65      0.121
# 264            12.5              0.56         0.49            2.40      0.064
# 636             9.6              0.88         0.28            2.40      0.086
# 510            12.4              0.42         0.49            4.60      0.073
# 177             7.5              0.52         0.42            2.30      0.087
# 1152            8.3              0.60         0.25            2.20      0.118
# ...

# %% [markdown]
# # Handling the outlier
