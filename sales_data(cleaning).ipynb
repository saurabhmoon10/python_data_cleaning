# %% [markdown]
# # DATA CLEANING

# %%
import pandas as pd

# %%
data=pd.read_csv(r"D:\sales_data.csv")

# %%
data
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# ## checking info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %% [markdown]
# ## finding null values

# %%
data.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year;             0
# dtype: int64

# %%
data.tail()
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 51285  CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286    MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287  MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288  MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289  CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 51285        Erica Bern  Corporate        California  United States      US
# 51286         Liz Preis   Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton   Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen   Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias   Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 51285     West  ...  Office Supplies      Binders
# ...

# %%
#checking the shape of data
data.shape
# Out:
# (51290, 21)

# %% [markdown]
# ### for column order_id

# %%
data["order_id"]
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
# checking the unique values 
data["order_id"].unique()
# Out:
# array(['AG-2011-2040', 'IN-2011-47883', 'HU-2011-1220', ...,
#        'MX-2014-108574', 'MO-2014-2560', 'CA-2014-156720'], dtype=object)

# %%
data["order_id"].nunique()
# Out:
# 25035

# %% [markdown]
# ### for column order_date

# %%
data["order_date"].dtypes
# Out:
# dtype('O')

# %%
data["order_date"].unique()
# Out:
# array(['01-01-2011', '01-02-2011', '01-03-2011', ..., '12/29/2014',
#        '12/30/2014', '12/31/2014'], dtype=object)

# %% [markdown]
# * The order of date is not in standard format.

# %%
data[data["order_date"].str.contains("-")]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 50060   US-2014-125213  12-12-2014  12/14/2014     First Class
# 50061     TU-2014-7890  12-12-2014  12/19/2014  Standard Class
# 50062   CA-2014-165099  12-12-2014  12/14/2014     First Class
# 50063     NI-2014-9730  12-12-2014  12/16/2014  Standard Class
# 50064     NI-2014-9730  12-12-2014  12/16/2014  Standard Class
#
#            customer_name      segment            state        country  market  \
# 0        Toby Braunhardt     Consumer      Constantine        Algeria  Africa
# ...

# %% [markdown]
# * There are total 20067 rows which contains wrong date format.

# %%
# replacing the "-" with "/"

data["order_date"]=data["order_date"].str.replace("-","/")

# %%
data
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01/01/2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01/01/2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01/01/2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01/01/2011  01-05-2011    Second Class
# 4        IN-2011-47883  01/01/2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
data
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01/01/2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01/01/2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01/01/2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01/01/2011  01-05-2011    Second Class
# 4        IN-2011-47883  01/01/2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# ### for column ship_date

# %%
# checking the info of this column
data["ship_date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51290 entries, 0 to 51289
# Series name: ship_date
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  object
# dtypes: object(1)
# memory usage: 400.8+ KB

# %%
data["ship_date"].unique()
# Out:
# array(['01-06-2011', '01-08-2011', '01-05-2011', ..., '01-05-2015',
#        '01-06-2015', '01-07-2015'], dtype=object)

# %%
# replacing the string "-" with "/".
data["ship_date"]=data["ship_date"].str.replace("-","/")

# %%
data
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01/01/2011  01/06/2011  Standard Class
# 1        IN-2011-47883  01/01/2011  01/08/2011  Standard Class
# 2         HU-2011-1220  01/01/2011  01/05/2011    Second Class
# 3      IT-2011-3647632  01/01/2011  01/05/2011    Second Class
# 4        IN-2011-47883  01/01/2011  01/08/2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01/04/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01/05/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01/02/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01/06/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01/04/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# * Successfully replaced the "-" with "/".

# %% [markdown]
# ### for column ship_mode

# %%
# checking the info
data["ship_mode"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51290 entries, 0 to 51289
# Series name: ship_mode
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  object
# dtypes: object(1)
# memory usage: 400.8+ KB

# %%
data["ship_mode"].unique()
# Out:
# array(['Standard Class', 'Second Class', 'Same Day', 'First Class'],
#       dtype=object)

# %% [markdown]
# * There are 4 unique values present in it.

# %%
#  counting the value based on data
data["ship_mode"].value_counts()
# Out:
# ship_mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %% [markdown]
# * In the data, There are maximum numbers of counts for standard class i.e., 30775.
# * There are 10309 numbers of counts for Second class.
# * There are 7505 numbers of counts for First class.
# * There are minimum numbers of counts for Same day i.e.,2701.

# %% [markdown]
# ### for customer_name columns

# %%
# checking the info
data["customer_name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51290 entries, 0 to 51289
# Series name: customer_name
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  object
# dtypes: object(1)
# memory usage: 400.8+ KB

# %%
data["customer_name"].values
# Out:
# array(['Toby Braunhardt', 'Joseph Holt', 'Annie Thurman', ...,
#        'Charlotte Melton', 'Tamara Dahlen', 'Jill Matthias'], dtype=object)

# %%
data["customer_name"].unique()
# Out:
# array(['Toby Braunhardt', 'Joseph Holt', 'Annie Thurman', 'Eugene Moren',
#        'Magdelene Morse', 'Kean Nguyen', 'Ken Lonsdale',
#        'Lindsay Williams', 'Larry Blacks', 'Dorothy Dickinson',
#        'Dennis Pardue', 'Stewart Visinsky', "Jas O'Carroll",
#        'Chris McAfee', 'Nat Gilpin', 'Jack Garza', 'Russell Applegate',
#        'Maya Herman', 'Beth Thompson', 'Arthur Prichep',
#        'Arthur Wiediger', 'Grant Thornton', 'Darren Powers',
#        'Bradley Drucker', 'Jasper Cacioppo', 'Jennifer Halladay',
#        'Michael Granlund', 'Phillina Ober', 'Shaun Weien',
#        'Shahid Hopkins', 'Brosina Hoffman', 'Robert Dilbeck',
#        'Grace Kelly', 'Khloe Miller', 'Mick Brown', 'Maria Etezadi',
#        'Maribeth Schnelling', 'Dave Poirier', 'Harry Marie',
#        'Lycoris Saunders', 'Alyssa Crouse', "Jack O'Briant",
#        'Adam Bellavance', 'Joy Smith', 'Henia Zydlo', 'Nicole Fjeld',
#        'Christopher Martinez', 'Vivek Sundaresam', 'Joe Elijah',
# ...

# %% [markdown]
# * There are few name in dataset with double cots.

# %%
#incomplete customer_name columns

# %% [markdown]
# ### for column product_name

# %%
data["product_name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51290 entries, 0 to 51289
# Series name: product_name
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  object
# dtypes: object(1)
# memory usage: 400.8+ KB

# %%
# checking the unique 
data["product_name"].unique()
# Out:
# array(['Tenex Lockers, Blue', 'Acme Trimmer, High Speed',
#        'Tenex Box, Single Width', ...,
#        'Panasonic BusinessÿTelephonesÿKX-T7736',
#        'Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, *Special Order',
#        'Acco Glide Clips'], dtype=object)

# %%
data["product_name"].nunique()
# Out:
# 3788

# %%
#replacements = {'*': '', 'ÿ': ' '}
data["product_name"]=data["product_name"].str.replace("[*ÿ]","",regex=True)

# %%
data
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01/01/2011  01/06/2011  Standard Class
# 1        IN-2011-47883  01/01/2011  01/08/2011  Standard Class
# 2         HU-2011-1220  01/01/2011  01/05/2011    Second Class
# 3      IT-2011-3647632  01/01/2011  01/05/2011    Second Class
# 4        IN-2011-47883  01/01/2011  01/08/2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01/04/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01/05/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01/02/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01/06/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01/04/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
data["product_name"].unique()
# Out:
# array(['Tenex Lockers, Blue', 'Acme Trimmer, High Speed',
#        'Tenex Box, Single Width', ...,
#        'Panasonic BusinessTelephonesKX-T7736',
#        'Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, Special Order',
#        'Acco Glide Clips'], dtype=object)

# %% [markdown]
# * special characters replaced with "" whitespace.

# %% [markdown]
# ### for column year

# %%
data["year"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51290 entries, 0 to 51289
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  object
# dtypes: object(1)
# memory usage: 400.8+ KB

# %%
data.drop(columns="year;",inplace=True,axis=1)

# %%
data["year"]=data["year;"].str.replace(";","",regex=True)

# %%
data
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01/01/2011  01/06/2011  Standard Class
# 1        IN-2011-47883  01/01/2011  01/08/2011  Standard Class
# 2         HU-2011-1220  01/01/2011  01/05/2011    Second Class
# 3      IT-2011-3647632  01/01/2011  01/05/2011    Second Class
# 4        IN-2011-47883  01/01/2011  01/08/2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01/04/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01/05/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01/02/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01/06/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01/04/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
# making the csv file
data.to_csv("final_sales_data.csv",index=False)
